# %% [markdown]
# > **Notebook-first lesson.** Run cells top-to-bottom. Environment-specific operations are written to be inspectable even when a service/device is unavailable.

# %% [markdown]
# # Lesson 58: Model serving with FastAPI
#
# Training is only half of an ML system.
#
# ## Inference API

# %%
from fastapi import FastAPI
from pydantic import BaseModel

app = FastAPI()

class Input(BaseModel):
    features: list[float]

@app.post("/predict")
def predict(inp: Input):
    # preprocess -> model -> postprocess
    return {"prediction": 0}

# %% [markdown]
# ## Production concerns
# - input validation
# - model loading
# - preprocessing consistency
# - batching
# - latency
# - concurrency
# - error handling
# - versioning
# - observability
#
# ## Exercise
# Serve one trained classifier. Add:
# - /health
# - /predict
# - model version in response
# - request validation
# - unit tests
#
# ## Important
# The exact same preprocessing used during training must be applied at inference.

# %% [markdown]
# ## Runnable activity
# Run this experiment and change at least one data, threshold, deployment, or systems assumption.

# %%
try:
    from fastapi import FastAPI
    from pydantic import BaseModel
    app=FastAPI()
    class Input(BaseModel):
        features:list[float]
    @app.get("/health")
    def health(): return {"status":"ok","model_version":"demo-1"}
    @app.post("/predict")
    def predict(inp:Input): return {"prediction":int(sum(inp.features)>0),"model_version":"demo-1"}
    print("routes:",[r.path for r in app.routes])
    print("direct function demo:",predict(Input(features=[1,-.2,.4])))
except Exception as e:
    print("Install fastapi and pydantic to run this activity:",e)

# %% [markdown]
# ## Engineering checkpoint
# Record the metric/result, the assumption you changed, and what would make this experiment invalid in a real deployment.
