# %% [markdown]
# > **Notebook-first lesson.** Run, perturb, measure, explain. The activity cell turns the lesson's core idea into an executable experiment.

# %% [markdown]
# ## Mathematical Framework
#
# Math companions for this lesson:
#
# - [Math 03 · Probability & Bayes](../../math/03_probability_bayes.ipynb)
# - [Math 04 · Statistics & Likelihood](../../math/04_statistics_likelihood.ipynb)
# - [Math 15 · Bayesian Uncertainty & Calibration](../../math/15_bayesian_uncertainty_calibration.ipynb)
#
# Use the math to separate **measured association from assumptions, optimization behavior from generalization, and confidence scores from calibrated uncertainty**.

# %% [markdown]
# # Lesson 74: Responsible ML and fairness concepts
#
# ML systems can produce unequal or harmful outcomes even when an aggregate metric looks good.
#
# ## Concepts
# - representation bias
# - measurement bias
# - historical bias
# - subgroup performance
# - fairness metrics
# - accessibility
# - human oversight
# - documentation
#
# Different fairness definitions can conflict, so context and intended use matter.
#
# ## Exercise
# Create a synthetic dataset with two groups whose data quality differs. Compare aggregate metrics against group-specific precision, recall and calibration.
#
# ## Documentation
# Practice writing:
# - intended use
# - out-of-scope use
# - data limitations
# - known failure modes
# - evaluation slices
# - monitoring plan

# %% [markdown]
# ## Runnable activity
# Execute this reduced-scale experiment, then change one assumption and compare the result.

# %%
from pathlib import Path
import os, sys
ROOT = Path(os.environ.get('COURSE_ROOT', next((str(p) for p in [Path.cwd(), *Path.cwd().parents] if (p / 'coursekit').is_dir()), '.'))).resolve()
if not (ROOT / 'coursekit').is_dir():
    raise RuntimeError('Open this notebook in the cloned ai-ml-learning repository.')
sys.path.insert(0, str(ROOT))
from coursekit.runtime import configure
SEED = 0
configure(SEED)

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score
rng=np.random.default_rng(0); n=4000
group=rng.integers(0,2,n)
y=rng.integers(0,2,n)
# Group 1 gets a noisier score to create unequal performance
score=y+rng.normal(0,np.where(group==0,.5,1.1))
pred=(score>.5).astype(int)
print("overall precision/recall",precision_score(y,pred),recall_score(y,pred))
for g in [0,1]:
    m=group==g
    print("group",g,"n",m.sum(),"precision",precision_score(y[m],pred[m]),"recall",recall_score(y[m],pred[m]))

# %% [markdown]
# ## Final checkpoint
# Add a Markdown cell with: **mechanism, evidence, limitation, and what you would test next.**
