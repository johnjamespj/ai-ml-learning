# %% [markdown]
# > **Notebook-first lesson.** Run cells top-to-bottom. Change parameters, break assumptions, and rerun. Original lesson content is preserved below.

# %% [markdown]
# ## Mathematical Framework
#
# This lesson is tied to the following math companions:
#
# - [Math 02 · Calculus & Matrix Calculus](../../math/02_calculus_matrix_calculus.ipynb)
# - [Math 04 · Statistics & Likelihood](../../math/04_statistics_likelihood.ipynb)
# - [Math 05 · Information Theory](../../math/05_information_theory.ipynb)
# - [Math 06 · Optimization](../../math/06_optimization.ipynb)
# - [Math 07 · Linear Models & Decision Boundaries](../../math/07_linear_models_decision_boundaries.ipynb)
# - [Math 08 · Regularization & Generalization](../../math/08_regularization_generalization.ipynb)
#
# Before treating the implementation as understood, identify **the mathematical objects, objective function, assumptions, gradient/update rule, and failure conditions** for the method used here.

# %% [markdown]
# # Lesson 08: Linear regression deeply
#
# ## Model
# For features X and weights w:
#
# y_hat = Xw + b
#
# The model learns parameters that minimize a loss, commonly mean squared error (MSE).
#
# ## From scratch

# %%
import numpy as np

rng = np.random.default_rng(42)
X = rng.uniform(-5, 5, (300, 1))
y = 3*X[:, 0] - 4 + rng.normal(0, 2, 300)

w = np.zeros(X.shape[1])
b = 0.0
lr = 0.01

for step in range(2000):
    pred = X @ w + b
    err = pred - y
    loss = np.mean(err**2)

    dw = (2/len(X)) * X.T @ err
    db = 2 * np.mean(err)

    w -= lr * dw
    b -= lr * db

print(w, b, loss)

# %% [markdown]
# ## Residuals
# A residual is y - y_hat. Residual plots can reveal curvature, changing variance, outliers, and other structure your model failed to capture.
#
# ## Metrics
# MSE penalizes large errors strongly. RMSE returns to the target's units. MAE is less sensitive to large errors. R² describes improvement relative to predicting the target mean.
#
# ## Experiment
# Compare your implementation with `sklearn.linear_model.LinearRegression`. Then add irrelevant features and extreme outliers.
#
# ## Questions
# Why is linear regression called linear? What assumptions make its interpretation useful? Why can low training error coexist with poor test performance?

# %% [markdown]
# ## Runnable activity
# Run this cell, inspect the output, then modify at least one assumption or hyperparameter and rerun.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
rng=np.random.default_rng(42)
X=rng.uniform(-5,5,(300,1)); y=3*X[:,0]-4+rng.normal(0,2,300)
m=LinearRegression().fit(X,y)
pred=m.predict(X)
res=y-pred
print("coef/intercept",m.coef_[0],m.intercept_,"RMSE",mean_squared_error(y,pred)**.5)
print("residual mean/std",res.mean(),res.std())
# Now inject 5 outliers and rerun to see coefficient sensitivity.

# %% [markdown]
# ## Explain it
# Write 3-5 sentences in a new Markdown cell: **what changed, why it changed, what metric/evidence supports your explanation, and one failure mode.**
