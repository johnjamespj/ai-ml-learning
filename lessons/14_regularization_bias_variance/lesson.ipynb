# %% [markdown]
# > **Notebook-first lesson.** Run cells top-to-bottom. All original examples and a runnable activity are included.

# %% [markdown]
# ## Mathematical Framework
#
# This lesson is tied to the following math companions:
#
# - [Math 02 · Calculus & Matrix Calculus](../../math/02_calculus_matrix_calculus.ipynb)
# - [Math 04 · Statistics & Likelihood](../../math/04_statistics_likelihood.ipynb)
# - [Math 05 · Information Theory](../../math/05_information_theory.ipynb)
# - [Math 06 · Optimization](../../math/06_optimization.ipynb)
# - [Math 07 · Linear Models & Decision Boundaries](../../math/07_linear_models_decision_boundaries.ipynb)
# - [Math 08 · Regularization & Generalization](../../math/08_regularization_generalization.ipynb)
#
# Before treating the implementation as understood, identify **the mathematical objects, objective function, assumptions, gradient/update rule, and failure conditions** for the method used here.

# %% [markdown]
# # Lesson 14: Bias, variance and regularization
#
# ## Bias vs variance
# Underfitting: the model cannot represent important structure.
# Overfitting: the model captures training-specific noise and fails to generalize.
#
# Training score alone cannot diagnose generalization.
#
# ## Regularization
# Regularization penalizes model complexity.
#
# L2 adds a squared-weight penalty:
# loss + lambda * sum(w²)
#
# L1 adds:
# loss + lambda * sum(abs(w))
#
# L1 can encourage sparse coefficients. L2 tends to shrink weights smoothly.
#
# ## Experiment
# Generate polynomial data. Fit polynomial models of increasing degree and plot training and validation errors. You should see the transition from underfit to useful fit to overfit.
#
# Then apply Ridge and Lasso.
#
# ## Questions
# Why does more model capacity sometimes hurt? Why does regularization introduce bias intentionally? Why should preprocessing live inside a cross-validation pipeline?

# %% [markdown]
# ## Runnable activity
# Execute, modify at least one parameter, and explain the observed change.

# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
rng=np.random.default_rng(0)
x=np.linspace(-3,3,120)[:,None]
y=np.sin(x[:,0])+rng.normal(0,.2,len(x))
Xtr,Xva,ytr,yva=train_test_split(x,y,test_size=.4,random_state=1)
for degree in [1,3,7,15]:
    m=make_pipeline(PolynomialFeatures(degree),StandardScaler(),Ridge(alpha=1e-3))
    m.fit(Xtr,ytr)
    print("degree",degree,"train",mean_squared_error(ytr,m.predict(Xtr)),"val",mean_squared_error(yva,m.predict(Xva)))

# %% [markdown]
# ## Explanation checkpoint
# Add a Markdown cell answering: **What mechanism produced the result? What evidence supports that? What is one failure mode?**
