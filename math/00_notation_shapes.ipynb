# %% [markdown]
# # Math 00 · Notation, Shapes, and the Language of ML
#
# **Companion lessons:** Lessons 01, 04, 19, 25, 37-45
#
# > **Math goal:** understand the objects, assumptions, derivation, and failure modes behind the algorithms, not just memorize formulas.

# %% [markdown]
# ## The mathematical objects
#
# Most ML can be described using:
#
# - scalar: $a\in\mathbb{R}$
# - vector: $\mathbf{x}\in\mathbb{R}^d$
# - matrix: $X\in\mathbb{R}^{n\times d}$
# - tensor: an array with more than two axes
# - function: $f:\mathbb{R}^d\to\mathbb{R}^k$
# - parameter vector: $\theta$
# - dataset: $\mathcal{D}=\{(\mathbf{x}_i,y_i)\}_{i=1}^n$
#
# A habit that prevents many bugs: **annotate every important tensor with its shape before writing the operation.**

# %%
from pathlib import Path
import os, sys
ROOT = Path(os.environ.get('COURSE_ROOT', next((str(p) for p in [Path.cwd(), *Path.cwd().parents] if (p / 'coursekit').is_dir()), '.'))).resolve()
if not (ROOT / 'coursekit').is_dir():
    raise RuntimeError('Open this notebook in the cloned ai-ml-learning repository.')
sys.path.insert(0, str(ROOT))
from coursekit.runtime import configure
SEED = 0
configure(SEED)

# %%
import numpy as np
n,d,k=5,3,2
X=np.random.default_rng(0).normal(size=(n,d))
W=np.random.default_rng(1).normal(size=(d,k))
b=np.zeros(k)
Y=X@W+b
print("X:",X.shape,"W:",W.shape,"b:",b.shape,"Y:",Y.shape)
assert Y.shape==(n,k)

# %% [markdown]
# ## Index notation
#
# Matrix multiplication
#
# $$
# Y=XW
# $$
#
# means
#
# $$
# Y_{ij}=\sum_{r=1}^{d}X_{ir}W_{rj}.
# $$
#
# The repeated index $r$ is summed over. This is the same operation NumPy performs with `X @ W`.

# %%
Y_manual=np.zeros((n,k))
for i in range(n):
    for j in range(k):
        for r in range(d):
            Y_manual[i,j]+=X[i,r]*W[r,j]
print(np.allclose(Y,Y_manual))

# %% [markdown]
# ## Broadcasting
#
# Broadcasting is convenient, but it can hide mathematical mistakes.
#
# For $Y=XW+b$, the same bias vector $b\in\mathbb{R}^k$ is added to every sample row.

# %%
print((X@W).shape,b.shape)
print("broadcast result:",(X@W+b).shape)

# %% [markdown]
# ### Activity
# Write the expected output shape before running each expression: `X.T @ X`, `X @ W`, `Y.T @ X`, and `X[:,None,:] - X[None,:,:]`.

# %% [markdown]
# ## Derivation checkpoint
# In a new Markdown cell, re-derive the main result without copying the notebook. State every variable's shape and every assumption used.

# %% [markdown]
# ## Engineering checkpoint
# Explain which approximation or assumption is most likely to break in a real system, and how you would detect that failure from data.
