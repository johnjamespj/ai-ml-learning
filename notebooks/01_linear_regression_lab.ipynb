# %% [markdown]
# # Linear Regression Lab Notebook
# Use this notebook after implementing `labs/lab01_linear_regression/starter.py`. Predict outcomes before running each experiment.

# %% [markdown]
# **Worked reference demonstration.** This notebook is not evidence you completed the starter. Use `tools/make_student_workspace.py` for your independent implementation and tests.

# %%
from pathlib import Path
import os, sys
ROOT = Path(os.environ.get('COURSE_ROOT', next((str(p) for p in [Path.cwd(), *Path.cwd().parents] if (p / 'coursekit').is_dir()), '.'))).resolve()
if not (ROOT / 'coursekit').is_dir():
    raise RuntimeError('Open this notebook in the cloned ai-ml-learning repository.')
sys.path.insert(0, str(ROOT))
from coursekit.runtime import configure
SEED = 0
configure(SEED)

# %%
import numpy as np
import matplotlib.pyplot as plt
from labs.lab01_linear_regression import solution as lab

# %% [markdown]
# ## Generate data
# Change noise and inspect how recovery changes.

# %%
rng=np.random.default_rng(42)
X=rng.uniform(-5,5,(300,1))
y=3*X[:,0]-4+rng.normal(0,.5,300)
plt.scatter(X[:,0],y,s=10);

# %% [markdown]
# ## Train
# Before running: predict whether the first or last loss should be larger.

# %%
w,b,history=lab.fit(X,y,lr=.01,steps=2000)
print(w,b,history[0],history[-1])
plt.figure(); plt.plot(history); plt.yscale('log'); plt.title('Training loss');

# %% [markdown]
# ## Reflection
# Explain what changes when the learning rate is 10x smaller and 10x larger. Then add outliers and inspect residuals.
