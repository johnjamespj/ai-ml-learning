# %% [markdown]
# # Exam 05: Attention, Transformers and LLM systems
#
# Prerequisites: Lessons 35–45; Math 11; Transformer and RAG papers
#
# 100 points. Attempt before reading instructor material. Numerical checks are not a mastery certificate.

# %%
from pathlib import Path
import sys, os
ROOT=Path(os.environ.get('COURSE_ROOT', next((str(p) for p in [Path.cwd(),*Path.cwd().parents] if (p/'assessment').is_dir()), '.')))
sys.path.insert(0,str(ROOT))
import numpy as np
RUN_CHECKS=False
print('NOT GRADED: implement the functions and set RUN_CHECKS=True.')

# %% [markdown]
# ## Derive (20 points)
#
# Derive the variance of q dot k under independent zero-mean unit-variance components. State when dividing by sqrt(dk) does not normalize variance. Explain permutation equivariance and positional information.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Code (30 points)
#
# Implement attention(Q,K,V,allow_mask) using NumPy for batch/time/features tensors. Return output and weights. True means allowed. Reject a fully masked row. Do not use a high-level attention function.
#
# Write your answer below.

# %%
def attention(Q, K, V, allow_mask):
    raise NotImplementedError("Scaled scores, stable softmax and value aggregation")

# %% [markdown]
# ## Debug (15 points)
#
# A decoder can see future tokens, a retrieval benchmark includes its evaluation queries in the indexed answer corpus, and generation quality is scored by fluency only. Propose three independent tests that expose these problems.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Design (20 points)
#
# Specify a no-position versus position ablation with identical initialization, balanced labels, majority baseline, validation-only selection and multiple seeds. For RAG define relevance labels and Recall@k/MRR separately from answer groundedness.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Defend (15 points)
#
# Explain what BERT, causal language modeling, LoRA and retrieval change, and what they leave unchanged. Distinguish a toy mechanism demo from original-benchmark reproduction.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Numerical self-check
#
# The full assessment still requires human review of reasoning, design and defense.

# %%
if RUN_CHECKS:
    from assessment.checks import check_submission
    print(check_submission('05_transformers', globals()))
else:
    print('NOT GRADED: checks have not run.')
