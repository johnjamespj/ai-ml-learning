# %% [markdown]
# # Exam 02: Classical ML and defensible evaluation
#
# Prerequisites: Lessons 08–18; classical benchmark
#
# 100 points. Attempt before reading instructor material. Numerical checks are not a mastery certificate.

# %%
from pathlib import Path
import sys, os
ROOT=Path(os.environ.get('COURSE_ROOT', next((str(p) for p in [Path.cwd(),*Path.cwd().parents] if (p/'assessment').is_dir()), '.')))
sys.path.insert(0,str(ROOT))
import numpy as np
RUN_CHECKS=False
print('NOT GRADED: implement the functions and set RUN_CHECKS=True.')

# %% [markdown]
# ## Derive (20 points)
#
# Derive the binary logistic negative log-likelihood and its weight gradient. Connect L2 regularization to both a Gaussian MAP prior and conditioning of a linear problem.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Code (30 points)
#
# Implement build_pipeline() returning StandardScaler and LogisticRegression in one sklearn Pipeline, and logistic_gradient(X,y,w) for mean binary cross-entropy without an intercept.
#
# Write your answer below.

# %%
def build_pipeline():
    raise NotImplementedError("Return a preprocessing and classification pipeline")

def logistic_gradient(X, y, w):
    raise NotImplementedError("Return a vector shaped like w")

# %% [markdown]
# ## Debug (15 points)
#
# A researcher standardizes the whole dataset, selects ten features using all labels, then cross-validates. Identify both leaks and write a corrected fit/transform/select order within each training fold.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Design (20 points)
#
# You have 40 recordings containing thousands of overlapping windows. Specify grouped train/validation/test splitting, a dummy baseline, nested or budgeted CV, model selection and a rare-event metric. Do not split neighboring windows randomly.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Defend (15 points)
#
# Explain why accuracy can be 99% for a useless detector; distinguish ranking, calibration and an operating threshold.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Numerical self-check
#
# The full assessment still requires human review of reasoning, design and defense.

# %%
if RUN_CHECKS:
    from assessment.checks import check_submission
    print(check_submission('02_classical_ml', globals()))
else:
    print('NOT GRADED: checks have not run.')
