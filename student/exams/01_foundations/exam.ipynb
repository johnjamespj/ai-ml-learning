# %% [markdown]
# # Exam 01: Mathematics and scientific Python
#
# Prerequisites: Lessons 00–08; Math 00–07
#
# 100 points. Attempt before reading instructor material. Numerical checks are not a mastery certificate.

# %%
from pathlib import Path
import sys, os
ROOT=Path(os.environ.get('COURSE_ROOT', next((str(p) for p in [Path.cwd(),*Path.cwd().parents] if (p/'assessment').is_dir()), '.')))
sys.path.insert(0,str(ROOT))
import numpy as np
RUN_CHECKS=False
print('NOT GRADED: implement the functions and set RUN_CHECKS=True.')

# %% [markdown]
# ## Derive (20 points)
#
# Derive the least-squares gradient using differentials. Show every shape. Derive Bayes posterior odds and explain the base-rate effect for prevalence 0.001, Pd 0.9 and Pfa 0.01.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Code (30 points)
#
# Implement mse_gradient(X,y,w) and posterior_positive(prevalence,pd,pfa). Validate probability arguments and give a clear failure for a zero-probability conditioning event.
#
# Write your answer below.

# %%
def mse_gradient(X, y, w):
    raise NotImplementedError("Implement the analytical gradient")

def posterior_positive(prevalence, pd, pfa):
    raise NotImplementedError("Implement Bayes rule with validation")

# %% [markdown]
# ## Debug (15 points)
#
# Explain and repair: X has shape (20,3), w has shape (3,1), y has shape (20,), and error = X @ w - y. Why does broadcasting produce a (20,20) matrix rather than a residual vector?
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Design (20 points)
#
# Design a Monte Carlo experiment verifying the sample-mean standard error decreases as 1/sqrt(n). Specify distribution, sample sizes, repeat count, seeds, plotting scale and expected discrepancy at finite sample sizes.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Defend (15 points)
#
# Explain why a numerical derivative is evidence for a derivation, not a proof. Distinguish variance, standard deviation and standard error.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Numerical self-check
#
# The full assessment still requires human review of reasoning, design and defense.

# %%
if RUN_CHECKS:
    from assessment.checks import check_submission
    print(check_submission('01_foundations', globals()))
else:
    print('NOT GRADED: checks have not run.')
