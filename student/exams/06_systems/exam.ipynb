# %% [markdown]
# # Exam 06: Full-system ML engineering and RF detection
#
# Prerequisites: Lessons 52–64 and 73–77; capstone baseline
#
# 100 points. Attempt before reading instructor material. Numerical checks are not a mastery certificate.

# %%
from pathlib import Path
import sys, os
ROOT=Path(os.environ.get('COURSE_ROOT', next((str(p) for p in [Path.cwd(),*Path.cwd().parents] if (p/'assessment').is_dir()), '.')))
sys.path.insert(0,str(ROOT))
import numpy as np
RUN_CHECKS=False
print('NOT GRADED: implement the functions and set RUN_CHECKS=True.')

# %% [markdown]
# ## Derive (20 points)
#
# Derive a known-signal likelihood-ratio test in Gaussian noise and its colored-noise whitening form. Derive precision from prevalence, Pd and Pfa. Explain why zero observed false alarms does not establish zero true Pfa.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Code (30 points)
#
# Implement threshold_for_pfa(noise_scores,alpha) using sorted ascending scores and rank ceil((n+1)*(1-alpha)); return infinity if the rank exceeds n. Use strict score > threshold. Implement operating_point(y,scores,threshold) returning tp,fp,pd,pfa.
#
# Write your answer below.

# %%
def threshold_for_pfa(noise_scores, alpha):
    raise NotImplementedError("Use the finite-sample calibration rank")

def operating_point(y, scores, threshold):
    raise NotImplementedError("Count outcomes; use strict >")

# %% [markdown]
# ## Debug (15 points)
#
# A detector tunes its threshold on test negatives, reports per-window random splits from one recording, normalizes each window so signal energy disappears, and serves with a different scaler. Correct the pipeline and artifact format.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Design (20 points)
#
# Specify disjoint training, validation, calibration, threshold-setting and final test data. Require Pd versus SNR, a fresh false-alarm estimate with intervals, unseen frequencies, clipping/colored-noise stress tests, serialization parity, latency percentiles and rollback criteria.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Defend (15 points)
#
# State intended and prohibited use, synthetic-to-real limitations, budget, drift versus performance monitoring, data provenance and the evidence needed before deploying on an actual receiver.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Numerical self-check
#
# The full assessment still requires human review of reasoning, design and defense.

# %%
if RUN_CHECKS:
    from assessment.checks import check_submission
    print(check_submission('06_systems', globals()))
else:
    print('NOT GRADED: checks have not run.')
