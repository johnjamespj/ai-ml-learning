# %% [markdown]
# # Exam 04: PyTorch, training systems and computer vision
#
# Prerequisites: Lessons 25–34; PyTorch classifier and CNN project
#
# 100 points. Attempt before reading instructor material. Numerical checks are not a mastery certificate.

# %%
from pathlib import Path
import sys, os
ROOT=Path(os.environ.get('COURSE_ROOT', next((str(p) for p in [Path.cwd(),*Path.cwd().parents] if (p/'assessment').is_dir()), '.')))
sys.path.insert(0,str(ROOT))
import numpy as np
RUN_CHECKS=False
print('NOT GRADED: implement the functions and set RUN_CHECKS=True.')

# %% [markdown]
# ## Derive (20 points)
#
# Derive the output spatial size and parameter count of a 2-D convolution with stride, padding and dilation. Contrast this with a dense layer over all pixels.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Code (30 points)
#
# Implement train_step(model,X,y,optimizer) using CrossEntropyLoss; return a scalar loss. Implement evaluate_accuracy(model,X,y) without changing weights or leaving the model in a different mode.
#
# Write your answer below.

# %%
def train_step(model, X, y, optimizer):
    raise NotImplementedError("One complete optimization step")

def evaluate_accuracy(model, X, y):
    raise NotImplementedError("Evaluate and restore the previous mode")

# %% [markdown]
# ## Debug (15 points)
#
# Find and repair: softmax before CrossEntropyLoss, omitted zero_grad, CPU labels with a CUDA model, and dropout left on during validation. Explain why each can fail differently.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Design (20 points)
#
# Design a controlled CNN-versus-MLP experiment with train/validation/test sets, matched data budget, justified parameter-count comparison, seed repeats, checkpoints and validation-only early stopping.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Defend (15 points)
#
# Distinguish model.eval(), no_grad() and requires_grad. Explain which RNG/optimizer/model states are required for a true training resume.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Numerical self-check
#
# The full assessment still requires human review of reasoning, design and defense.

# %%
if RUN_CHECKS:
    from assessment.checks import check_submission
    print(check_submission('04_pytorch', globals()))
else:
    print('NOT GRADED: checks have not run.')
