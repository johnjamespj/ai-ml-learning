# %% [markdown]
# # Exam 03: Neural networks from first principles
#
# Prerequisites: Lessons 19–24; NumPy MLP; backprop paper
#
# 100 points. Attempt before reading instructor material. Numerical checks are not a mastery certificate.

# %%
from pathlib import Path
import sys, os
ROOT=Path(os.environ.get('COURSE_ROOT', next((str(p) for p in [Path.cwd(),*Path.cwd().parents] if (p/'assessment').is_dir()), '.')))
sys.path.insert(0,str(ROOT))
import numpy as np
RUN_CHECKS=False
print('NOT GRADED: implement the functions and set RUN_CHECKS=True.')

# %% [markdown]
# ## Derive (20 points)
#
# For Z1=XW1+b1, A1=ReLU(Z1), Z2=A1W2+b2, derive all cross-entropy gradients using row-batched convention. Show why two linear layers collapse into one affine map.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Code (30 points)
#
# Implement relu_backward(upstream,z) and a stable mean cross_entropy_logits(logits,y) using log-sum-exp. Do not clip probabilities to hide overflow or underflow.
#
# Write your answer below.

# %%
def relu_backward(upstream, z):
    raise NotImplementedError("Apply the local Jacobian")

def cross_entropy_logits(logits, y):
    raise NotImplementedError("Use stable log-sum-exp")

# %% [markdown]
# ## Debug (15 points)
#
# A network reaches 50% on XOR. Its developer removed the hidden activation, divides the gradient by batch size twice, and initializes every hidden unit identically. Explain the distinct effect of each bug and how to isolate it.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Design (20 points)
#
# Plan a gradient check away from ReLU kinks and a tiny-batch overfit test. Give absolute/relative tolerances, finite-difference step sizes, and an ablation with and without nonlinearity.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Defend (15 points)
#
# Distinguish backpropagation from the optimizer. Explain vanishing gradients, residual Jacobians and the assumptions behind He initialization.
#
# Write your answer below.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Numerical self-check
#
# The full assessment still requires human review of reasoning, design and defense.

# %%
if RUN_CHECKS:
    from assessment.checks import check_submission
    print(check_submission('03_neural_networks', globals()))
else:
    print('NOT GRADED: checks have not run.')
